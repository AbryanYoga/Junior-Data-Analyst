# %%
import pandas as pd

# Assuming df is already loaded in the kernel from previous steps.
# If not, uncomment the line below to load it:
# df = pd.read_excel('/content/Dataset_Kemacetan_Surakarta_300_Data.xlsx')

print("--- df.info() ---")
df.info()
print("\n")

print("--- df.isnull().sum() (Missing Values per Column) ---")
print(df.isnull().sum())
print("\n")

print("--- df.duplicated().sum() (Total Duplicate Rows) ---")
print(f"Total duplicated rows: {df.duplicated().sum()}")
# To see the duplicated rows, uncomment the line below:
# if df.duplicated().sum() > 0: display(df[df.duplicated(keep=False)])
print("\n")

print("--- df.describe(include='all') (Descriptive Statistics) ---")
print(df.describe(include='all'))
# Out:
# --- df.info() ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            300 non-null    int64
#  1   Nama Jalan    300 non-null    object
#  2   Kecamatan     300 non-null    object
#  3   Kab/Kota      300 non-null    object
#  4   Titik Lokasi  300 non-null    object
#  5   Latitude      300 non-null    float64
#  6   Longitude     300 non-null    float64
#  7   Skor          300 non-null    int64
#  8   Kategori      300 non-null    object
#  9   Kecepatan     300 non-null    int64
#  10  Volume/jam    300 non-null    int64
#  11  Jam Pagi      300 non-null    object
#  12  Jam Sore      300 non-null    object
#  13  Penyebab      300 non-null    object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 32.9+ KB
#
#
# --- df.isnull().sum() (Missing Values per Column) ---
# ID              0
# Nama Jalan      0
# ...
